# %%
import json
import pandas as pd

# Load the JSON file
with open("sb_reports.json", "r") as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data)

loads = df[df['slug'].str.startswith('load_')]
transforms = df[df['slug'].str.startswith('trfm_')]
extracts = df[df['slug'].str.startswith('extr_')]

print(loads)
print(transforms)
print(extracts)
# Out:
#                                       slug caption
# 1                          load_ta_from_tw     NaN  \
# 2                          load_db_schools     NaN
# 3                 load_db_school_groupings     NaN
# 4   load_db_student_grouping_registrations     NaN
# 5                         load_db_students     NaN
# 11                              load_twtar     NaN
# 12                                 load_tw     NaN
# 15                        load_ta_from_uid     NaN
# 16              load_sb_student_exceptions     NaN
# 18                            load_sb_taqr     NaN
# 19             load_sb_formatted_responses     NaN
# 20                          load_ta_detail     NaN
# 22         load_item_register_consolidated     NaN
#
#                                           description  structure
# 1                                  Loads test windows  dataframe  \
# 2           Loads all available schools in a district  dataframe
# ...

# %%
# pip install networkx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.5 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
